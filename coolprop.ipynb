# %% [markdown]
# <a href="https://colab.research.google.com/github/Ekaterina713/Labpython/blob/main/coolprop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy.optimize import fsolve 
def z(p):
  x,y=p
  return(x**2+x*y+7,y**2+np.sin(x)+10)
k=fsolve(z,(0,1))
print(k)
# Out:
# [-0.54372666  0.26653707]

# %% [markdown]
# Функция coolprops

# %%
pip install CoolProp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 35.2 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import CoolProp.CoolProp as ct
import matplotlib.pyplot as plt
t=np.linspace(274,380,100)
p=101325
D=ct.PropsSI("D","T",t,"P",p,"water")
plt.plot(t,D,"r")
plt.scatter(373.15,ct.PropsSI("D","T",373.15,"P",p,"water"))
plt.title("Зависимость D от t при постоянном давлении")
plt.xlabel('t')
plt.ylabel("D")
plt.grid()
plt.show()
